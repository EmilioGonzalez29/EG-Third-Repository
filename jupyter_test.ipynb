# %% [markdown]
# ##Probando Jupyter Notebook en VS Code
# #Código de Prueba

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.DataFrame({'a':[2, 3, 4, 5], 'b':[4, 9, 16, 25]})

df.plot(title='A y B')
plt.show()
